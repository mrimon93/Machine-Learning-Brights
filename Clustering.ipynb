# %% [markdown]
# Hello and Welcome to the Clustering part of Machine Learning module in Data-Enineer 2022/2023.
#
# Here we are training, predicting and plotting data from gender_classification_v7.csv file.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
# %matplotlib inline

# %%
#Importing the CC_General CSV Datasets with Pandas 
df=pd.read_csv("CC_GENERAL.csv")
df
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001    40.900749           0.818182      95.40              0.00
# 1     C10002  3202.467416           0.909091       0.00              0.00
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 3     C10004  1666.670542           0.636364    1499.00           1499.00
# 4     C10005   817.714335           1.000000      16.00             16.00
# ...      ...          ...                ...        ...               ...
# 8945  C19186    28.493517           1.000000     291.12              0.00
# 8946  C19187    19.183215           1.000000     300.00              0.00
# 8947  C19188    23.398673           0.833333     144.40              0.00
# 8948  C19189    13.457564           0.833333       0.00              0.00
# 8949  C19190   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# ...

# %%
#Filling the value missing rows with mean value 

f['CREDIT_LIMIT'].fillna((df['CREDIT_LIMIT'].mean()), inplace=True)
df['MINIMUM_PAYMENTS'].fillna((df['MINIMUM_PAYMENTS'].mean()), inplace=True)

df
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001    40.900749           0.818182      95.40              0.00
# 1     C10002  3202.467416           0.909091       0.00              0.00
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 3     C10004  1666.670542           0.636364    1499.00           1499.00
# 4     C10005   817.714335           1.000000      16.00             16.00
# ...      ...          ...                ...        ...               ...
# 8945  C19186    28.493517           1.000000     291.12              0.00
# 8946  C19187    19.183215           1.000000     300.00              0.00
# 8947  C19188    23.398673           0.833333     144.40              0.00
# 8948  C19189    13.457564           0.833333       0.00              0.00
# 8949  C19190   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# ...

# %%
#Dropping the Cust_id to avoid any issues where it contains some letters etc
df = df.drop(["CUST_ID"],axis=1)

# %%
df.head()
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    40.900749           0.818182      95.40              0.00
# 1  3202.467416           0.909091       0.00              0.00
# 2  2495.148862           1.000000     773.17            773.17
# 3  1666.670542           0.636364    1499.00           1499.00
# 4   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# ...

# %%
df.shape
# Out:
# (8950, 18)

# %%
#We had a issue here, we accidently imported "import sklearn.cluster as KMeans" instead of "from sklearn.cluster import KMeans"  
#Here we are defining the empty model and thereafter we are fit/train our model with our current data that is given from the csv-file
kmeans = KMeans(3)
kmeans.fit_predict(df)
# Out:
# array([0, 1, 1, ..., 0, 0, 0], dtype=int32)

# %%
#kmeans.labels_ is an array containing the cluster labels generated by running the k-means clustering algorithm on a set of data. 
#We are adding a new column with the name 'cluster' and asiging the values from the array 
#Optional: We watnt to study the first 100 rows and plot it in 2D and 3D
df['cluster'] = kmeans.labels_
df['100_BALANCE']=df['BALANCE'].head(100)
df['100_CREDIT_LIMIT']=df['CREDIT_LIMIT'].head(100)

# %%
#Plot the values in in 2D

plt.scatter(df['100_BALANCE'],df['100_CREDIT_LIMIT'], c=df['cluster'], cmap= 'rainbow')
plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1], c='black')
plt.xlabel('Balance left in the Account')
plt.ylabel('Credit Limit')
# Out:
# Text(0, 0.5, 'Credit Limit')

# %%
# Plot the values in 3D

fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111,projection="3d")
ax.scatter(df['100_CREDIT_LIMIT'],df['100_CREDIT_LIMIT'],df['PURCHASES'],c=df['cluster'], cmap= 'rainbow')

ax.set_xlabel("Balance left in the Account")
ax.set_ylabel("Credit Limit")
ax.set_zlabel("Purchases")
# Out:
# Text(0.5, 0, 'Payments')

# %% [markdown]
# # New Section
